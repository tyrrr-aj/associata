# %% [markdown]
# ## Data

# %%
results = {
    'Balanced': [
        {
            'structure_size': 1360,
            'inference_times': [
                11.85,
                6.78,
                4.75,
                3.82,
                3.16,
                2.7,
                2.62,
                2.26,
                2.36,
                2.17,
                2.33,
                2.1,
                2.13,
                2.07,
                1.91,
                1.96,
            ]
        },
        {
            'structure_size': 5921,
            'inference_times': [
                559.43,
                289.92,
                196.01,
                151.22,
                121.76,
                106.92,
                92.33,
                86.17,
                80.43,
                78.7,
                75.16,
                75.11,
                71.95,
                69.01,
                66.45,
                66.1,
            ]
        },
        {
            'structure_size': 10734,
            'inference_times': [
                997.24,
                517.1,
                358.91,
                266.72,
                220.17,
                196.51,
                179.19,
                148.29,
                148.22,
                143.27,
                135.24,
                130.8,
                126.52,
                120.28,
                119.56,
                114.49,
            ]
        },
        {
            'structure_size': 15870,
            'inference_times': [
                1936.75,
                1036.74,
                719.59,
                545.94,
                446.16,
                394.24,
                348.23,
                319.25,
                298.77,
                284.89,
                280.30,
                267.98,
                259.70,
                253.97,
                236.81,
                234.51,
            ]
        }
    ],

    'Big VNG': [
        {
            'structure_size': 1763,
            'inference_times': [
                15.02,
                9.12,
                6.64,
                5.13,
                4.45,
                4.00,
                3.74,
                3.51,
                3.50,
                3.48,
                3.50,
                3.42,
                3.39,
                3.37,
                3.30,
                3.31,
            ]
        },
        {
            'structure_size': 6868,
            'inference_times': [
                575.04,
                305.52,
                206.06,
                159.17,
                132.18,
                118.21,
                104.32,
                94.13,
                89.02,
                90.73,
                83.59,
                82.53,
                79.40,
                76.44,
                74.87,
                75.24,
            ]
        },
        {
            'structure_size': 12523,
            'inference_times': [
                992.22,
                518.38,
                352.94,
                275.16,
                226.46,
                192.47,
                176.61,
                161.73,
                154.18,
                148.52,
                148.51,
                141.65,
                141.36,
                133.40,
                129.16,
                126.58,
            ]
        },
        {
            'structure_size': 18055,
            'inference_times': [
                1969.49,
                1036.59,
                708.03,
                546.04,
                449.30,
                389.83,
                352.00,
                335.27,
                316.84,
                306.76,
                293.34,
                284.56,
                277.84,
                271.61,
                271.12,
                271.90,
            ]
        },
    ],

    'Little VNG': [
        {
            'structure_size': 1290,
            'inference_times': [
                10.25,
                5.83,
                4.11,
                3.34,
                2.81,
                2.48,
                2.38,
                2.35,
                2.06,
                2.06,
                1.95,
                1.94,
                1.92,
                1.92,
                1.86,
                1.82,
            ]
        },
        {
            'structure_size': 5779,
            'inference_times': [
                545.95,
                290.28,
                195.68,
                149.96,
                120.79,
                103.31,
                92.66,
                88.12,
                84.06,
                81.11,
                77.96,
                77.43,
                73.04,
                70.45,
                68.79,
                69.38,
            ]
        },
        {
            'structure_size': 10454,
            'inference_times': [
                953.49,
                498.58,
                339.30,
                260.16,
                215.49,
                182.50,
                161.32,
                150.98,
                145.07,
                140.88,
                139.08,
                133.47,
                128.48,
                129.39,
                126.06,
                122.29,
            ]
        },
        {
            'structure_size': 15577,
            'inference_times': [
                1952.89,
                1030.41,
                687.25,
                524.01,
                427.73,
                367.45,
                327.80,
                306.93,
                294.15,
                287.95,
                273.67,
                264.87,
                257.95,
                253.90,
                242.43,
                240.66,
            ]
        },
    ],

    'Categorical': [
        {
            'structure_size': 1289,
            'inference_times': [
                5.39,
                2.75,
                1.96,
                1.61,
                1.33,
                1.36,
                1.09,
                1.05,
                .99,
                1.05,
                1.02,
                .96,
                .93,
                .91,
                .88,
                .88,
            ]
        },
        {
            'structure_size': 6467,
            'inference_times': [
                281.80,
                146.68,
                100.17,
                76.53,
                61.60,
                52.96,
                47.86,
                44.15,
                42.07,
                41.08,
                39.54,
                39.25,
                37.25,
                35.76,
                35.29,
                34.07,
            ]
        },
        {
            'structure_size': 11867,
            'inference_times': [
                480.37,
                253.72,
                171.78,
                132.23,
                109.52,
                93.99,
                85.64,
                77.53,
                75.23,
                71.14,
                68.37,
                66.34,
                64.15,
                62.12,
                61.21,
                61.38,
            ]
        },
        {
            'structure_size': 16937,
            'inference_times': [
                982.22,
                516.09,
                355.25,
                275.62,
                223.54,
                194.71,
                172.54,
                161.12,
                151.91,
                148.57,
                141.33,
                137.44,
                134.03,
                130.36,
                125.39,
                124.78,
            ]
        },
    ]
}

# %% [markdown]
# ## Plots

# %%
from matplotlib import pyplot as plt

# %%
n_cores = list(range(1, 17))
markers = ['o', 's', '^', 'd']

# Plotting the data
plt.figure(figsize=(10, 6))

for exp_size, marker in zip(results['Balanced'], markers):
    single_core_time = exp_size['inference_times'][0]
    plt.plot(n_cores, [100 * single_core_time / time for time in exp_size['inference_times']], label=f'{exp_size["structure_size"]} nodes', marker=marker)

# Adding labels and title
plt.xlabel('Number of CPU cores')
plt.ylabel('Speed-up [%]')
plt.title('Average speedup achieved for the "Balanced" case')

# Adding legend and grid
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
n_cores = list(range(1, 17))
markers = ['o', 's', '^', 'd']
cases = ['Balanced', 'Big VNG', 'Little VNG', 'Categorical']
titles = {
    'Balanced': '(1) Numerical VNGs of similar size',
    'Big VNG': '(2) Numerical VNGs, one of them with large number of VNs',
    'Little VNG': '(3) Numerical VNGs, one of them with small number of VNs',
    'Categorical': '(4) Mixed VNGs: half of them numeriacl, half categorical'
}

fig, axs = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle('Average speedup achieved for varying AGDNN setup', fontsize=18)
fig.subplots_adjust(top=0.98)

for idx, case in enumerate(cases):
    row = idx // 2
    col = idx % 2
    ax = axs[row, col]
    
    for exp_size, marker in zip(results[case], markers):
        single_core_time = exp_size['inference_times'][0]
        speedup = [100 * single_core_time / time for time in exp_size['inference_times']]
        ax.plot(n_cores, speedup, label=f'{exp_size["structure_size"]} nodes', marker=marker)
    
    ax.set_xlabel('Number of CPU cores', fontsize=14)
    ax.set_ylabel('Speed-up [%]', fontsize=14)
    ax.set_title(titles[case], fontsize=16)
    ax.legend(fontsize=12)
    ax.grid(True)

plt.tight_layout(rect=[0, 0.03, 1, 0.98])
plt.savefig('results-strong-speedup.eps', format='eps', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
n_cores = list(range(1, 17))
markers = ['o', 's', '^', 'd']

# Plotting the data
plt.figure(figsize=(10, 6))

for exp_size, marker in zip(results['Regular'], markers):
    single_core_time = exp_size['inference_times'][0]
    plt.plot(n_cores, [100 * single_core_time / time for time in exp_size['inference_times']], label=f'{exp_size["structure_size"]} nodes', marker=marker)

# Adding labels and title
plt.xlabel('Number of CPU cores')
plt.ylabel('Speed-up [%]')
plt.title('Average speedup achieved for the "Regular" case')

# Adding legend and grid
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# # Big experiments

# %%
results = {
    'Balanced': [
        {
            'structure_size': 7951,
            'inference_times': [
                870.44,
                761.29,
                374.99,
                181.63,
                103.82,
                56.75,
                44.56,
                48.45,
                48.15,
            ]
        },
        {
            'structure_size': 15870,
            'inference_times': [
                1849.53,
                1161.59,
                795.51,
                358.36,
                198.06,
                106.08,
                77.30,
                92.13,
                101.49,
            ]
        },
        {
            'structure_size': 26733,
            'inference_times': [
                2838.83,
                1768.25,
                1047.28,
                538.88,
                293.90,
                163.65,
                128.23,
                158.03,
                160.89,
            ]
        },
        {
            'structure_size': 41706,
            'inference_times': [
                3815.15,
                2947.29,
                1352.76,
                691.82,
                384.99,
                236.44,
                214.23,
                223.01,
                217.67,
            ]
        }
    ],

    'Big VNG': [
        {
            'structure_size': 9047,
            'inference_times': [
                1077.14,
                694.16,
                431.99,
                188.34,
                113.90,
                67.74,
                57.50,
                67.38,
                68.66,
            ]
        },
        {
            'structure_size': 18055,
            'inference_times': [
                1852.04,
                1430.46,
                793.37,
                380.70,
                224.62,
                138.13,
                117.38,
                136.71,
                134.92,
            ]
        },
        {
            'structure_size': 30789,
            'inference_times': [
                2838.56,
                1729.41,
                1274.38,
                558.69,
                324.25,
                211.67,
                202.13,
                221.39,
                223.77,
            ]
        },
        {
            'structure_size': 48478,
            'inference_times': [
                3320.70,
                2313.70,
                1347.33,
                689.56,
                422.12,
                301.23,
                301.31,
                314.97,
                324.29,
            ]
        },
    ],

    'Little VNG': [
        {
            'structure_size': 7810,
            'inference_times': [
                863.84,
                754.25,
                406.59,
                187.00,
                99.75,
                60.14,
                42.97,
                49.08,
                54.13,
            ]
        },
        {
            'structure_size': 15577,
            'inference_times': [
                2534.01,
                1572.96,
                739.77,
                359.91,
                200.27,
                111.43,
                91.49,
                105.12,
                105.50,
            ]
        },
        {
            'structure_size': 26148,
            'inference_times': [
                2806.19,
                2210.69,
                1065.81,
                535.86,
                296.59,
                167.06,
                140.46,
                163.94,
                164.36,
            ]
        },
        {
            'structure_size': 40633,
            'inference_times': [
                3625.74,
                2156.04,
                1332.49,
                696.90,
                380.23,
                223.25,
                194.34,
                221.63,
                213.45,
            ]
        },
    ],

    'Categorical': [
        {
            'structure_size': 8480,
            'inference_times': [
                451.62,
                303.22,
                193.61,
                101.67,
                56.02,
                36.04,
                25.79,
                24.54,
                31.02,
            ]
        },
        {
            'structure_size': 15870,
            'inference_times': [
                938.47,
                554.59,
                367.73,
                183.99,
                100.51,
                57.65,
                42.37,
                52.19,
                55.26,
            ]
        },
        {
            'structure_size': 28883,
            'inference_times': [
                1424.65,
                935.04,
                555.37,
                266.26,
                153.49,
                84.91,
                71.73,
                83.10,
                89.59,
            ]
        },
        {
            'structure_size': 45868,
            'inference_times': [
                1813.88,
                1076.02,
                678.38,
                348.68,
                200.55,
                119.13,
                103.67,
                125.39,
                134.04,
            ]
        },
    ]
}

# %%
from matplotlib import pyplot as plt

# %%
n_cores = [2**n for n in range(9)]
markers = ['o', 's', '^', 'd']

# Plotting the data
plt.figure(figsize=(10, 6))

for exp_size, marker in zip(results['Balanced'], markers):
    single_core_time = exp_size['inference_times'][0]
    plt.plot(n_cores[:-2], [100 * single_core_time / time for time in exp_size['inference_times'][:-2]], label=f'{exp_size["structure_size"]} nodes', marker=marker)

# Adding labels and title
plt.xlabel('Number of CPU cores')
plt.ylabel('Speed-up [%]')
plt.title('Average speedup achieved for the "Balanced" case')

# Adding legend and grid
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
cases = ['Balanced', 'Big VNG', 'Little VNG', 'Categorical']

fig, axs = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle('Average speedup achieved for different cases', fontsize=16)

for idx, case in enumerate(cases):
    row = idx // 2
    col = idx % 2
    ax = axs[row, col]
    
    for exp_size, marker in zip(results[case], markers):
        single_core_time = exp_size['inference_times'][0]
        speedup = [100 * single_core_time / time for time in exp_size['inference_times']]
        ax.plot(n_cores[:-2], speedup[:-2], label=f'{exp_size["structure_size"]} nodes', marker=marker)
    
    ax.set_xlabel('Number of CPU cores')
    ax.set_ylabel('Speed-up [%]')
    ax.set_title(f'{case} case')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.savefig('results-strong-speedup.eps', format='eps', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Plotting the data
plt.figure(figsize=(10, 6))

for exp_size, marker in zip(results['Regular'], markers):
    single_core_time = exp_size['inference_times'][0]
    plt.plot(n_cores, [100 * single_core_time / time for time in exp_size['inference_times']], label=f'{exp_size["structure_size"]} nodes', marker=marker)

# Adding labels and title
plt.xlabel('Number of CPU cores')
plt.ylabel('Speed-up [%]')
plt.title('Average speedup achieved for the "Regular" case')

# Adding legend and grid
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 4
#       1 # Plotting the data
#       2 plt.figure(figsize=(10, 6))
# ----> 4 for exp_size, marker in zip(results['Regular'], markers):
#       5     single_core_time = exp_size['inference_times'][0]
#       6     plt.plot(n_cores, [100 * single_core_time / time for time in exp_size['inference_times']], label=f'{exp_size["structure_size"]} nodes', marker=marker)
#
# KeyError: 'Regular'

# %% [markdown]
# # Improved visibility

# %%
from matplotlib import pyplot as plt

# %%
n_cores = list(range(1, 17))
markers = ['o', 's', '^', 'd']

# Plotting the data
plt.figure(figsize=(10, 6))

for exp_size, marker in zip(results['Balanced'], markers):
    single_core_time = exp_size['inference_times'][0]
    plt.plot(n_cores, [100 * single_core_time / time for time in exp_size['inference_times']], label=f'{exp_size["structure_size"]} nodes', marker=marker)

# Adding labels and title
plt.xlabel('Number of CPU cores', fontsize=16)
plt.ylabel('Speed-up [%]', fontsize=16)
plt.title('Average speedup achieved for the "Balanced" case', fontsize=20, fontweight='bold')

# Physical/logical CPU cores indication
plt.axvline(x=8, color='purple', linestyle='--', linewidth=2)
plt.text(8, plt.ylim()[1]*0.15, 'Physical cores ', ha='right', va='center', fontsize=14, fontweight='bold', color='purple')
plt.text(8, plt.ylim()[1]*0.15, ' Logical cores', ha='left', va='center', fontsize=14, fontweight='bold', color='purple')

# Adding legend and grid
plt.legend(fontsize=18)
plt.grid(True)

# Show the plot
plt.show()

# %%
import numpy as np

speedups = [[], [], [], []]

for vng_layout in results.keys():
    for i, exp_size in enumerate(results[vng_layout]):
        single_core_time = exp_size['inference_times'][0]
        speedup = [100 * single_core_time / time for time in exp_size['inference_times']]
        speedups[i].append(speedup)

speedups = np.array(speedups)

avg_speedups = [[sum(structure_size_speedups[:,n_cores]) / 4 for n_cores in range(16)] for structure_size_speedups in speedups]

# %%
avg_speedups
# Out:
# [[100.0,
#   177.82162370113417,
#   250.017557745388,
#   311.16644617270094,
#   370.63998276409967,
#   406.0047174783892,
#   444.7655090405859,
#   475.4400143013399,
#   493.31969029726974,
#   497.1495733945921,
#   497.94973658000674,
#   523.3189624081682,
#   528.2074834791172,
#   536.0807391167889,
#   559.7864080340646,
#   558.5137712417061],
#  [100.0,
#   190.34321624308555,
#   281.19911045638156,
#   365.87598100195333,
#   450.9866144630228,
#   517.5592534538623,
#   583.7818667974931,
#   629.486990565186,
#   665.2071687278683,
#   675.9270097673452,
#   711.3097479638162,
#   716.1573339094426,
#   751.4337515513814,
#   781.4762540366962,
#   800.5265574347147,
#   806.1580195525489],
#  [100.0,
#   191.2080442427459,
#   279.9104222143668,
#   366.06818716776183,
#   443.0434378706336,
#   514.1353269998008,
#   567.5783999970472,
#   634.2808674615228,
#   653.0385902979959,
#   679.0460205295279,
#   698.4187378920428,
#   725.3443148232234,
# ...

# %%
n_cores = list(range(1, 17))
markers = ['o', 's', '^', 'd']
labels = ['1300 neurons', '6000 neurons', '11000 neurons', '16000 neurons']

# Plotting the data
plt.figure(figsize=(10, 6))

for avg_speedup, marker, label in zip(avg_speedups, markers, labels):
    plt.plot(n_cores, avg_speedup, label=label, marker=marker)

# Adding labels and title
plt.xlabel('Number of CPU cores', fontsize=16)
plt.ylabel('Speed-up [%]', fontsize=16)
plt.title('Average speedup', fontsize=20, fontweight='bold')

# Physical/logical CPU cores indication
plt.axvline(x=8, color='purple', linestyle='--', linewidth=2)
plt.text(8, plt.ylim()[1]*0.15, 'Physical cores ', ha='right', va='center', fontsize=14, fontweight='bold', color='purple')
plt.text(8, plt.ylim()[1]*0.15, ' Logical cores', ha='left', va='center', fontsize=14, fontweight='bold', color='purple')

# Adding legend and grid
plt.legend(fontsize=18)
plt.grid(True)

plt.savefig('results-strong-speedup-avg.svg', format='svg')

# Show the plot
plt.show()

# %%
n_cores = list(range(1, 17))
markers = ['o', 's', '^', 'd']
cases = ['Balanced', 'Big VNG', 'Little VNG', 'Categorical']
titles = {
    'Balanced': '(1) Numerical VNGs\nof similar size',
    'Big VNG': '(2) Numerical VNGs,\none of them with large number of VNs',
    'Little VNG': '(3) Numerical VNGs,\none of them with small number of VNs',
    'Categorical': '(4) Mixed VNGs:\nhalf of them numeriacl, half categorical'
}

fig, axs = plt.subplots(2, 2, figsize=(16, 12))
# fig, axs = plt.subplots(1, 4, figsize=(30, 6))
fig.suptitle('Average speedup achieved for varying AGDNN setup', fontsize=25, fontweight='bold')

for idx, case in enumerate(cases):
    row = idx // 2
    col = idx % 2
    ax = axs[row, col]
    # ax = axs[idx]
    
    for exp_size, marker in zip(results[case], markers):
        single_core_time = exp_size['inference_times'][0]
        speedup = [100 * single_core_time / time for time in exp_size['inference_times']]
        ax.plot(n_cores, speedup, label=f'{exp_size["structure_size"]:,} nodes'.replace(',', ' '), marker=marker)
    
    ax.set_xlabel('Number of CPU cores', fontsize=18)
    ax.set_ylabel('Speed-up [%]', fontsize=18)
    ax.set_title(titles[case], fontsize=22)
    ax.legend(fontsize=15)
    ax.grid(True)

    ax.axvline(x=8, color='purple', linestyle='--', linewidth=2)
    ax.text(8, ax.get_ylim()[1]*0.15, 'Physical cores ', ha='right', va='center', fontsize=14, fontweight='bold', color='purple')
    ax.text(8, ax.get_ylim()[1]*0.15, ' Logical cores', ha='left', va='center', fontsize=14, fontweight='bold', color='purple')

plt.tight_layout(rect=[0, 0.03, 1, 0.98], w_pad=5.0, h_pad=5.0)
plt.savefig('results-strong-speedup-square.svg', format='svg')
plt.show()
