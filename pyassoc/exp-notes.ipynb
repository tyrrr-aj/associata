# %% [markdown]
# # Notes on AGDS RL experiments

# %% [markdown]
# ## Proper actions_taken plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Referential tabular-like AGDS results

# %% [markdown]
# #### Individual episodes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Moving average (n = 150)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Association in value function

# %% [markdown]
# ### Association on unknown state-action pairs

# %%
get_q(SA):
    for known SA -> return ON[SA]->VN_value
    for unknown SA -> return assoc_on(SA)->VN_value

default weights (VN->VN: subtract abs(TargetReprValue - OwnReprValue) / (VNGMaxValue - VNGMinValue))
constant vng min/max (given at creation)

# %% [markdown]
# #### Results

# %% [markdown]
# ##### Individual episodes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Moving average (n = 150)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Association on unknown state-action pairs

# %% [markdown]
# ### Association on all (known and unknown) state-action pairs

# %% [markdown]
# get_q(SA):
#     return assoc_on(SA)->VN_value
#
# default weights (VN->VN: subtract abs(TargetReprValue - OwnReprValue) / (VNGMaxValue - VNGMinValue))
#
# constant vng min/max (given at creation)
#
# weight_vn_to_on(.) = 1 (const)

# %% [markdown]
# #### Results

# %% [markdown]
# ##### Individual episodes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Moving average (n = 150)

# %% [markdown]
# ![image.png](attachment:image.png)
